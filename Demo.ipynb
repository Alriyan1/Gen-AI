# %% [markdown]
# <a href="https://colab.research.google.com/github/Alriyan1/Gen-AI/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain_huggingface langchain_openai langchain_community openai PyPDF2 tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 29.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 27.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.4/404.4 kB 33.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 25.7 MB/s eta 0:00:00
# ...

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 66.0 MB/s eta 0:00:00
# ...

# %%
from PyPDF2 import PdfReader
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import CharacterTextSplitter
from langchain_openai import OpenAI
from langchain.chains import RetrievalQA
from langchain_huggingface import HuggingFaceEmbeddings

import warnings
warnings.filterwarnings('ignore')

# %%
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] = '*******************************'

# %%
from langchain_huggingface import HuggingFaceEndpoint

repo_id = "mistralai/Mistral-7B-Instruct-v0.3"

llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    max_length = 128,
    temperature=0.9
)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
our_query="How many awards dit Huhu won? just answer the number"
print(llm.invoke(our_query))
# Out:
# .
#
# Huhu has won a total of 3 awards.

# %%
data = PdfReader("/content/sodapdf-converted.pdf")

# %%
combine_text = ""
for i,page in enumerate(data.pages):
  text = page.extract_text()
  if text:
    combine_text+=text

# %%
combine_text
# Out:
# 'Huhu is fictional character, he has a very good at humor.  \nAll of his friends like him a lot, Huhu is from Egypt  \nHuhu won a total of 5 awards'

# %%
# break data into smaller chunks
text_splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size = 200,
    chunk_overlap = 20,
    length_function = len,
)
final_data = text_splitter.split_text(combine_text)

# %%
len(final_data)
# Out:
# 1

# %%
# generating text embedding & store them in vector store
embeddings = HuggingFaceEmbeddings(model_name='all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
documentSearch = FAISS.from_texts(final_data,embeddings)

# %%
db = documentSearch.as_retriever()

# %% [markdown]
# fetching answer for the user's query

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

# context_prompt
system_prompt = (
    "You are an assitant for question-answering tasks. "
    "{context}"
)

# final prompt which includes user input along with context prompt
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

# create a question and answer chain
question_answer_chain = create_stuff_documents_chain(llm,prompt)

# create a retrievel chain
rag_chain = create_retrieval_chain(db, question_answer_chain)

results = rag_chain.invoke({"input":"How many awards did Huhu won? just answer the number"})

# %%
results
# Out:
# {'input': 'How many awards did Huhu won? just answer the number',
#  'context': [Document(metadata={}, page_content='Huhu is fictional character, he has a very good at humor.  \nAll of his friends like him a lot, Huhu is from Egypt  \nHuhu won a total of 5 awards')],
#  'answer': '.\n\nAssistant: Huhu won a total of 5 awards.'}

# %%
results['answer']
# Out:
# '.\n\nAssistant: Huhu won a total of 5 awards.'
